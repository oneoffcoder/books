# %%
source('./network/congress.R')
# Out:
# Loading required package: gRbase
#
#
# Attaching package: ‘gRbase’
#
#
# The following objects are masked from ‘package:bnlearn’:
#
#     ancestors, children, nodes, parents
#
#
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”

# %%
graphviz.chart(b, grid=TRUE, main='BBN')
# Out:
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Plot with title “BBN”

# %%
nodes_=c('AZ_02','IN_07','MA_02','MD_08','TN_09','FL_20','VA_08','CT_05','TX_18','MA_08','MA_06','MS_02','OH_11','MD_07','MD_04','VA_04','KY_03','CA_51','CA_39','NY_16','MO_01','CA_17','CA_15','RI_01','LA_02','GA_04','TX_30','FL_24','MO_05','GA_13','NC_12','FL_22','MI_11','FL_25','OH_13','TX_37','FL_10','CT_03','OR_04','AZ_03','MA_07','PA_12','MI_06','NY_14','CA_49','CA_16','CA_50','NJ_06','CA_02','CA_26','CA_18','CA_24','NY_05','WA_09','CA_29','CA_43','RI_02','ME_01','PA_08','CT_02','PA_04','IL_08','HI_01','PA_07','IL_06','CA_04','NY_13','NY_15','CA_38','CA_07','CO_01','VA_03','NC_04','TX_07','OH_03','MA_03','NY_08','NY_10','CA_42','OR_06','CA_52','CA_14','CA_46','NY_26','CT_01','AK_99','IL_03','NC_08','GA_10','TN_01','GA_12','VA_06','FL_17','AL_06','MD_02','IL_10','NV_03','IN_03','TX_15','IN_04','NC_07','OK_01','TX_38','TX_23','WI_06','TX_24','GA_09','MD_01','SC_02','SC_04','TX_17','TX_03','TX_01','TX_22','CO_08','PA_10','MO_07','OK_02','TX_21','OH_08','GA_06','WA_10','MN_03','PA_02','WA_02','MI_08','PA_06','KS_03','IN_01','TX_20','AZ_04','TX_16','IL_01','CO_04','IL_14','NJ_08','TX_34','NJ_11','FL_23','NJ_01','NY_18','MI_07','ME_02','TX_05','TX_11','TX_08','TX_26','TX_12','TX_10','MI_13','NC_14','NC_01','NH_01','IL_17','WA_08','NM_03','OR_05','NJ_07','CA_33','VA_10','MN_07','IA_02','IA_03','MO_08','MN_08','NE_01','MN_06','WI_03','MO_02','WI_08','MI_03','IL_11','AL_05','MI_09','FL_03','AL_01','MI_01','GA_08','MI_04','SC_07','IN_02','TN_06','NC_03','MI_10','PA_15','KY_01','OH_04','KY_04','OH_09','TX_25','AL_03','SC_06','AZ_06','CT_04','AR_04','AL_04','MS_04','MS_01','TN_07','OH_01','FL_11','CO_07','NV_02','TN_03','KY_02','NC_11','AR_03','NC_10','TX_31','WA_03','VI_99','CA_23','NY_21','PA_16','OH_07','IN_05','MA_01','PA_09','FL_21','OH_05','PA_13','OH_15','ND_99','VA_09','SD_99','TN_04','TN_02','FL_04','KY_05','NY_22','FL_18','PR_99','FL_06','FL_26','FL_15','KS_04','NE_03','FL_16','NY_04','IN_06','NC_05','PA_17','UT_01','FL_07','CA_11','OR_02','LA_05','MT_01','UT_02','WI_01','CA_48','CA_27','AS_99','NY_19','NY_11','NM_02','ID_02','CA_03','NY_03','UT_03','AZ_01','MO_06','VA_02','OK_04','AR_02','GA_11','OK_03','CA_45','CA_20','LA_01','OH_10','MA_05','MT_02','FL_01','NJ_10','FL_14','GA_02','FL_09','AZ_07','WA_07','NY_09','IL_04','CA_10','NY_07','CA_28','CO_02','MN_05','CA_37','TX_09','IL_07','NY_20','NY_12','CA_34','PA_05','CA_36','TX_35','TX_36','SC_05','WA_01','GA_07','TX_29','AL_07','NJ_03','TX_33','TX_28','NJ_02','TX_06','VT_99','NC_02','MN_02','NM_01','NE_02','NJ_04','CA_35','VA_11','VA_07','TN_08','NY_25','IL_05','AL_02','KS_02','WY_99','MA_09','NV_04','TX_02','MA_04','TX_27','IL_13','CO_06','WA_05','TX_04','NC_06','IL_02','NJ_09','OH_12','AR_01','WV_02','NY_23','FL_28','TX_19','NY_01','NY_02','MI_05','NC_13','WV_01','GA_14','CA_25','IN_09','WI_05','CA_41','MP_99','GU_99','CA_09','ID_01','CA_22','FL_13','IN_08','PA_11','MO_03','VA_01','OK_05','KY_06','MO_04','CA_13','LA_06','OH_14','MD_05','VA_05','CA_19','MI_12','AZ_08','FL_08','FL_19','SC_01','WA_06','WI_04','TX_32','OR_03','CA_31','MN_04','CO_03','TX_14','NY_06','TN_05','NV_01','NJ_05','DE_99','PA_03','FL_02','FL_27','CA_06','WI_07','CA_05','CA_21','MI_02','IL_16','CO_05','KS_01','MN_01','LA_04','OH_06','MD_03','SC_03','OR_01','GA_05','CA_44','CA_08','AZ_09','NH_02','FL_12','FL_05','NC_09','NY_17','CA_32','CA_40','NY_24','OH_02','GA_03','CA_01','IA_04','IL_12','PA_14','TX_13','UT_04','LA_03','WI_02','IL_15','MD_06','GA_01','PA_01','CA_30','MS_03','IA_01','WA_04','IL_09','NJ_12','CA_47','DC_99','HI_02','CA_12','AZ_05')

# %%
querygrain(t, nodes=nodes_)
# Out:
# $AZ_02
# AZ_02
#        no       yes
# 0.8646704 0.1353296
#
# $MT_02
# MT_02
#        no       yes
# 0.8498047 0.1501953
#
# $FL_01
# FL_01
#        no       yes
# 0.8493445 0.1506555
#
# $VA_05
# VA_05
#        no       yes
# 0.8488718 0.1511282
#
# $DC_99
# DC_99
#        no       yes
# 0.8972182 0.1027818
#
# $AZ_05
# AZ_05
#        no       yes
# 0.8306116 0.1693884
#
# $VA_08
# VA_08
#         no        yes
# 0.97168059 0.02831941
#
# $IN_07
# IN_07
#         no        yes
# 0.93175487 0.06824513
#
# $MA_02
# MA_02
#         no        yes
# 0.93221913 0.06778087
#
# $MD_08
# MD_08
#         no        yes
# 0.96100279 0.03899721
#
# $TN_09
# TN_09
#         no        yes
# 0.93616527 0.06383473
#
# $FL_20
# FL_20
#         no        yes
# 0.96169916 0.03830084
#
# $AZ_07
# AZ_07
#         no        yes
# 0.92873451 0.07126549
#
# $IL_04
# IL_04
#         no        yes
# 0.94802037 0.05197963
#
# $CA_10
# CA_10
#         no        yes
# 0.95219398 0.04780602
#
# $TX_35
# TX_35
# ...
