# %%
from darkstar.inference import from_json

m = from_json('./data/congress-tree.json')

# %%
[m.get_posterior_by_name(n) for n in m.get_node_names()]
# Out:
# [[{'AK_99': 'no', '__p__': '0.98305'}, {'AK_99': 'yes', '__p__': '0.01695'}],
#  [{'AL_01': 'no', '__p__': '0.97563'}, {'AL_01': 'yes', '__p__': '0.02437'}],
#  [{'AL_02': 'no', '__p__': '0.96239'}, {'AL_02': 'yes', '__p__': '0.03761'}],
#  [{'AL_03': 'no', '__p__': '0.98860'}, {'AL_03': 'yes', '__p__': '0.01140'}],
#  [{'AL_04': 'no', '__p__': '0.98584'}, {'AL_04': 'yes', '__p__': '0.01416'}],
#  [{'AL_05': 'no', '__p__': '0.99188'}, {'AL_05': 'yes', '__p__': '0.00812'}],
#  [{'AL_06': 'no', '__p__': '0.98886'}, {'AL_06': 'yes', '__p__': '0.01114'}],
#  [{'AL_07': 'no', '__p__': '0.95543'}, {'AL_07': 'yes', '__p__': '0.04457'}],
#  [{'AR_01': 'no', '__p__': '0.97571'}, {'AR_01': 'yes', '__p__': '0.02429'}],
#  [{'AR_02': 'no', '__p__': '0.98445'}, {'AR_02': 'yes', '__p__': '0.01555'}],
#  [{'AR_03': 'no', '__p__': '0.98654'}, {'AR_03': 'yes', '__p__': '0.01346'}],
#  [{'AR_04': 'no', '__p__': '0.98630'}, {'AR_04': 'yes', '__p__': '0.01370'}],
# ...

# %%
m.assert_evidences_by_name({'CA_11': {'yes': 1.0, 'no': 0.0}})
[m.get_posterior_by_name(n) for n in m.get_node_names()]
# Out:
# [[{'AK_99': 'no', '__p__': '0.98305'}, {'AK_99': 'yes', '__p__': '0.01695'}],
#  [{'AL_01': 'no', '__p__': '0.97563'}, {'AL_01': 'yes', '__p__': '0.02437'}],
#  [{'AL_02': 'no', '__p__': '0.96239'}, {'AL_02': 'yes', '__p__': '0.03761'}],
#  [{'AL_03': 'no', '__p__': '0.98860'}, {'AL_03': 'yes', '__p__': '0.01140'}],
#  [{'AL_04': 'no', '__p__': '0.98584'}, {'AL_04': 'yes', '__p__': '0.01416'}],
#  [{'AL_05': 'no', '__p__': '0.99188'}, {'AL_05': 'yes', '__p__': '0.00812'}],
#  [{'AL_06': 'no', '__p__': '0.98886'}, {'AL_06': 'yes', '__p__': '0.01114'}],
#  [{'AL_07': 'no', '__p__': '0.95543'}, {'AL_07': 'yes', '__p__': '0.04457'}],
#  [{'AR_01': 'no', '__p__': '0.97571'}, {'AR_01': 'yes', '__p__': '0.02429'}],
#  [{'AR_02': 'no', '__p__': '0.98445'}, {'AR_02': 'yes', '__p__': '0.01555'}],
#  [{'AR_03': 'no', '__p__': '0.98654'}, {'AR_03': 'yes', '__p__': '0.01346'}],
#  [{'AR_04': 'no', '__p__': '0.98630'}, {'AR_04': 'yes', '__p__': '0.01370'}],
# ...
