# %%
source('./network/covid.R')
# Out:
# Loading required package: gRbase
#
#
# Attaching package: ‘gRbase’
#
#
# The following objects are masked from ‘package:bnlearn’:
#
#     ancestors, children, nodes, parents
#
#
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”

# %%
graphviz.chart(b, grid=TRUE, main='BBN')
# Out:
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Warning message:
# “Any reference to graphNEL objects will be removed in future versions of gRbase
# Please use igraphs instead
# ”
# Plot with title “BBN”

# %%
nodes_=c('GenderFemale','ExcessSweat','Sorethroat','Runnynose','Chestpain','LossTaste','TestPositive','Headaches','Chills','MuscleAches','Fever','Wheezing','AbdominalPain','LossSmell','LossAppetite','Fatigue','Age30orMore','Difficultybreathing','Diarrhea','Cough')

querygrain(t, nodes=nodes_)
# Out:
# $GenderFemale
# GenderFemale
#     No    Yes
# 0.4208 0.5792
#
# $ExcessSweat
# ExcessSweat
#     No    Yes
# 0.9327 0.0673
#
# $LossSmell
# LossSmell
#         No        Yes
# 0.91971952 0.08028048
#
# $Runnynose
# Runnynose
#     No    Yes
# 0.4164 0.5836
#
# $Fever
# Fever
#        No       Yes
# 0.3764361 0.6235639
#
# $LossAppetite
# LossAppetite
#        No       Yes
# 0.7678756 0.2321244
#
# $MuscleAches
# MuscleAches
#     No    Yes
# 0.6464 0.3536
#
# $Difficultybreathing
# Difficultybreathing
#     No    Yes
# 0.7852 0.2148
#
# $Diarrhea
# Diarrhea
#     No    Yes
# 0.7245 0.2755
#
# $Sorethroat
# Sorethroat
#       No      Yes
# 0.618208 0.381792
#
# $Wheezing
# Wheezing
#        No       Yes
# 0.7743819 0.2256181
#
# $AbdominalPain
# AbdominalPain
#    No   Yes
# 0.859 0.141
#
# $Chestpain
# Chestpain
#     No    Yes
# 0.8112 0.1888
#
# $Fatigue
# Fatigue
#     No    Yes
# 0.6182 0.3818
#
# $Age30orMore
# Age30orMore
# 18_to_29      30+
#   0.3709   0.6291
#
# $Cough
# ...

# %%
querygrain(setEvidence(t, nodes='TestPositive', states='Positive'), nodes=nodes_)
# Out:
# $GenderFemale
# GenderFemale
#        No       Yes
# 0.4186085 0.5813915
#
# $ExcessSweat
# ExcessSweat
#         No        Yes
# 0.92344959 0.07655041
#
# $LossSmell
# LossSmell
#        No       Yes
# 0.8896179 0.1103821
#
# $Runnynose
# Runnynose
#        No       Yes
# 0.4140205 0.5859795
#
# $Fever
# Fever
#        No       Yes
# 0.3663144 0.6336856
#
# $LossAppetite
# LossAppetite
#        No       Yes
# 0.7452325 0.2547675
#
# $MuscleAches
# MuscleAches
#        No       Yes
# 0.6388473 0.3611527
#
# $Difficultybreathing
# Difficultybreathing
#        No       Yes
# 0.7784159 0.2215841
#
# $Diarrhea
# Diarrhea
#        No       Yes
# 0.7220823 0.2779177
#
# $Sorethroat
# Sorethroat
#       No      Yes
# 0.614421 0.385579
#
# $Wheezing
# Wheezing
#        No       Yes
# 0.7662668 0.2337332
#
# $AbdominalPain
# AbdominalPain
#        No       Yes
# 0.8588987 0.1411013
#
# $Chestpain
# Chestpain
#        No       Yes
# 0.7293998 0.2706002
#
# $Fatigue
# Fatigue
# ...
