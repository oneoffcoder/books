# %% [markdown]
# # Environment
#
# This matters because a broken environment wastes more time than a weak model. You should verify Python, PyTorch, CUDA, and device availability first so the rest of the tutorial is about learning, not setup drift.

# %% [markdown]
# ## nvidia-smi

# %%
# %%sh
# if command -v nvidia-smi >/dev/null 2>&1; then
#     nvidia-smi
# else
#     echo "nvidia-smi is not available; continuing with CPU-compatible checks."
# fi
# Out:
# Fri Nov  1 02:51:24 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 418.56       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:01:00.0  On |                  N/A |
# | 24%   31C    P8    13W / 250W |    773MiB / 10986MiB |      4%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# ## nvcc

# %%
# %%sh
# if command -v nvcc >/dev/null 2>&1; then
#     nvcc --version
# else
#     echo "nvcc is not available; CUDA toolkit checks are optional for this notebook."
# fi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %% [markdown]
# ## PyTorch

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
torch.__version__
# Out:
# '1.3.0'
